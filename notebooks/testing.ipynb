# %%
# -*- coding: utf-8 -*-
import sys
sys.path.insert(0, '../')
import numpy as np
import matplotlib.pyplot as plt 
from src.utils import positional_encoding

max_length = 100
model_dim = 64

positional_encodings = positional_encoding(max_length, model_dim)

# Plotting
plt.figure(figsize=(10, 8))
plt.imshow(positional_encodings, cmap='viridis')
plt.colorbar()
plt.title('Positional Encoding')
plt.xlabel('Depth')
plt.ylabel('Position')
plt.show()
